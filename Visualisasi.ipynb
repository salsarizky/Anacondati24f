# %%
# Matplotlip, SeaBorn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.random.seed(42)
Bulan = ['Januari','Februari','Maret','April','Mei','Juni','Juli','Agustus','September','Oktober','November','Desembar']
Minggu_1 = np.random.randint(200000,700000,12)
Minggu_2 = np.random.randint(200000,700000,12)
Minggu_3 = np.random.randint(200000,700000,12)
Minggu_4 = np.random.randint(200000,700000,12)

data = {
    'Bulan' : Bulan,
    'Minggu1' : Minggu_1,
    'Minggu2' : Minggu_2,
    'Minggu3' : Minggu_3,
    'Minggu4' : Minggu_4
}
df = pd.DataFrame(data)
df ['Total_Pengeluaran'] = df [['Minggu1','Minggu2','Minggu3','Minggu4']].sum(axis=1)
df
# Out:
#         Bulan  Minggu1  Minggu2  Minggu3  Minggu4  Total_Pengeluaran
# 0     Januari   321958   287498   527069   686232            1822757
# 1    Februari   346867   574871   452709   592752            1967199
# 2       Maret   331932   588468   399041   356730            1676171
# 3       April   565838   375203   467455   546622            1955118
# 4         Mei   459178   391335   303355   584681            1738549
# 5        Juni   319879   478167   435796   349503            1583345
# 6        Juli   310268   241090   414176   330523            1296057
# 7     Agustus   407892   529365   384779   202747            1524783
# 8   September   254886   264820   547449   323855            1391010
# 9     Oktober   337337   462913   621909   652366            2074525
# 10   November   675602   521879   665148   265725            2128354
# 11   Desembar   630410   394027   458795   329981            1813213

# %%
#Diagram Bar
#Buat canvas
plt.figure(figsize=(12,6)) #widht, height -> inch
plt.bar(df['Bulan'],df['Total_Pengeluaran'],color='pink')
plt.xticks(rotation=45)
plt.tight_layout()
plt.title("Total Pengeluaran Mahsiswa Per Bulan")
plt.ylabel("Rupiah")
plt.grid(axis='y')
plt.show()

# %%
#Tren pengeluaran Per Minggu dalam satu tahun

plt.figure(figsize=(10,5))

for minggu in ['Minggu1','Minggu2','Minggu3','Minggu4']:
    plt.plot(df['Bulan'],df[minggu],marker='o',label=minggu)

plt.title("Tren Pengeluaran Mahasiswa per Minggu")
plt.ylabel("Rupiah")
plt.legend()
plt.grid(True)
plt.xticks(rotation =45)
plt.tight_layout()
plt.show()

# %%
#Diagram pie (proporsi pengeluaran perbulan)
plt.figure(figsize=(6,6))
plt.pie(df['Total_Pengeluaran'],labels=df['Bulan'], startangle=90, autopct='%1.1f%%',colors=plt.cm.Pastel2.colors)
plt.axis('equal')
plt.title("Proporsi Pengeluaran Mahasiswa Per Bulan")
plt.show()

# %%
#Model Ai -> scikit , sklearn
from sklearn.linear_model import LinearRegression
df['Bulan'] = np.arange(1,13)

X = df[['Bulan']]
y = df['Total_Pengeluaran']

model = LinearRegression()
model.fit(X,y)

prediksi_13 = model.predict([[13]])[0]
print(f"Prediksi Pengeluaran Mahasiswa Bulan Januari: {prediksi_13:,.0f}")
plt.figure(figsize=(10,10))
plt.boxplot(df['Total_Pengeluaran'])
plt.show
# Out:
# Prediksi Pengeluaran Mahasiswa Bulan Januari: 1,756,335
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#LOAD DATA
#Skenario analisa Data
#1.Mencari pengeluaran terbesar per Bulan
#2.Tren Pengeluaran mahasiswa tiap minggu
#3. Pengeluaran Mahasiswa Terbanyak per 6 bulan

df = pd.read_csv("https://www.kaggle.com/datasets/samanfatima7/2020-2025-apple-stock-dataset")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[99], line 7
#       1 #LOAD DATA
#       2 #Skenario analisa Data
#       3 #1.Mencari pengeluaran terbesar per Bulan
#       4 #2.Tren Pengeluaran mahasiswa tiap minggu
#       5 #3. Pengeluaran Mahasiswa Terbanyak per 6 bulan
# ----> 7 df = pd.read_csv("https://www.kaggle.com/datasets/samanfatima7/2020-2025-apple-stock-dataset")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 9, saw 2
